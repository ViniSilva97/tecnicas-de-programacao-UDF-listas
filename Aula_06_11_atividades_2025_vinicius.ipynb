# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniSilva97/tecnicas-de-programacao-UDF-listas/blob/main/Aula_06_11_atividades_2025_vinicius.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operadores

# %%
2 ** 3
# Out:
# 8

# %%
23/7
# Out:
# 3.2857142857142856

# %%
23%7
# Out:
# 2

# %%
5 + 5 * 5 / 5
# Out:
# 10.0

# %%
4 ** (4//2) + 7
# Out:
# 23

# %%
'''faça um programa que leia dois números inteiros e faça a soma deles '''

n1 = int(input('Digite um número inteiro: '))
n2 = int(input('Digite mais um número inteiro: '))

print ('A soma de ', n1, '+', n2, 'é:', n1+n2)
# Out:
# Digite um número inteiro: 1
# Digite mais um número inteiro: 3
# A soma de  1 + 3 é: 4

# %%
'''Faça um programa que leia a nota que um
aluno tirou em P1(Prova 1) e P2(Prova 2)
Calcule a média aritmética.
Exiba esse resultado na tela.
TAREFA 2
Conceitos'''

nota1 = float(input('Digite a nota da prova 1: '))
nota2 = float(input('Digite a nota da prova 2: '))

print ('A média das notas é:', (nota1+nota2)/2)
# Out:
# Digite a nota da prova 1: 5
# Digite a nota da prova 2: 2
# A média das notas é: 3.5

# %%
'''Leia um nome armazenado em uma variável
e imprima Olá, nome_pessoa!'''

nome = input('Digite seu nome: ')

print ('Olá,', nome, '!')
# Out:
# Digite seu nome: Vinicius
# Olá, Vinicius !

# %%
'''Solicite que o usuário digite seu nome.
Solicite que o usuários digite seu ano de nascimento
Exiba na tela:
nome_usuario nasceu em ano_nascimento'''

nome = input('Digite seu nome: ')
ano = int(input('Digite seu ano de nascimento: '))

print (nome, 'nasceu em', ano)
# Out:
# Digite seu nome: Vinciius
# Digite seu ano de nascimento: 1997
# Vinciius nasceu em 1997

# %%
'''TAREFA 5
Solicite que o usuário digite seu nome e sua idade.
Imprima “Olá, nome! Você tem idade anos?”
Imprima o ano de nascimento da pessoa (ignore meses e dias)
Imprima o nome da pessoa idade vezes (João tem 18, imprime JoãoJoão...)'''

nome = input('Digite seu nome: ')
idade = int(input('Digite sua idade: '))

print ('Olá,', nome, '! Você tem', idade, 'anos?')
print ('Você nasceu em', 2022-idade)
print (nome*idade)
# Out:
# Digite seu nome: Vinicius
# Digite sua idade: 28
# Olá, Vinicius ! Você tem 28 anos?
# Você nasceu em 1994
# ViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusViniciusVinicius

# %%
'''TAREFA 6
Solicite ao usuário que digite três notas
depois calcule e exiba a média ponderada.'''

nota1 = float(input('Digite a primeira nota: '))
nota2 = float(input('Digite a segunda nota: '))
nota3 = float(input('Digite a terceira nota: '))

media = (nota1+ nota2 + nota3)/3

print ('A média ponderada é:', media)
# Out:
# Digite a primeira nota: 8.6
# Digite a segunda nota: 9
# Digite a terceira nota: 5.5
# A média ponderada é: 7.7

# %%
'''TAREFA 7
Solicite ao usuário três notas e seus
respectivos pesos, depois calcule e exiba a
média ponderada'''

nota1 = float(input('Digite a primeira nota: '))
peso1 = float(input('Digite o peso da primeira nota: '))
nota2 = float(input('Digite a segunda nota: '))
peso2 = float(input('Digite o peso da segunda nota: '))
nota3 = float(input('Digite a terceira nota: '))
peso3 = float(input('Digite o peso da terceira nota: '))

media = (nota1*peso1 + nota2*peso2 + nota3*peso3)/(peso1+peso2+peso3)

print ('A média ponderada é:', media)
# Out:
# Digite a primeira nota: 5
# Digite o peso da primeira nota: 1
# Digite a segunda nota: 6
# Digite o peso da segunda nota: 3
# Digite a terceira nota: 8
# Digite o peso da terceira nota: 2
# A média ponderada é: 6.5

# %%
'''TAREFA 8
Peça ao usuário um número e exiba a soma
de seus dígitos'''

n1 = int(input('Digite um número: '))
soma = 0

for digito in n1:
    soma += digito

print ('A soma dos dígitos é:', soma)
# Out:
# Digite um número: 55
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2437043595.py in <cell line: 0>()
#       6 soma = 0
#       7
# ----> 8 for digito in n1:
#       9     soma += digito
#      10
#
# TypeError: 'int' object is not iterable

# %%
'''TAREFA 9
Peça ao usuário uma palavra e exiba-a
invertida sem usar laços'''

palavra = input('Digite uma palavra: ')

print (palavra[::-1])
# Out:
# Digite uma palavra: vinicuis
# siuciniv
